# %%
# !git clone https://huggingface.co/spaces/Shawal777/nyankolev1
# Out:
# Cloning into 'nyankolev1'...
# remote: Enumerating objects: 4, done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (4/4), 1.29 KiB | 1.29 MiB/s, done.

# %%
# %cd nyankolev1
# Out:
# /content/nyankolev1

# %%
# !touch app.py

# %%
# !cat app.py
# Out:
# import gradio as gr
#
# def greet(name):
#     return "Hello " + name + "!!"
#
# demo = gr.Interface(fn=greet, inputs="audio", outputs="text")
# demo.launch()

# %%
# !git add app.py && git commit -m 'Add application file' && git push
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@55a72ecb5adb.(none)')
